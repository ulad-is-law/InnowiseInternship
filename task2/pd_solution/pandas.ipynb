# %%
import pandas as pd

# %%
def load_data(file_path: str) -> pd.DataFrame:
    try:
        raw_df = pd.read_excel(file_path)
    except FileNotFoundError:
        print(f"Error, file not found on the path: {file_path}")
        return pd.DataFrame()
    return raw_df

raw_df = load_data('task_2_data_ex.xlsx')

# %%
df_fin = raw_df[raw_df['produced_material_release_type'] =="FIN"]

df_fin
# Out:
#       year  month  produced_material  produced_material_production_type  \
# 0     2024      1              10000                               8002
# 11    2024      2              10000                               8002
# 22    2024      3              10000                               8002
# 33    2024      4              10000                               8002
# 44    2024      5              10000                               8002
# ...    ...    ...                ...                                ...
# 1265  2024      8              10009                               8002
# 1276  2024      9              10009                               8002
# 1287  2024     10              10009                               8002
# 1298  2024     11              10009                               8002
# 1309  2024     12              10009                               8002
#
#      produced_material_release_type  produced_material_quantity  \
# 0                               FIN                       990.0
# 11                              FIN                       960.0
# 22                              FIN                       968.0
# 33                              FIN                      1006.0
# 44                              FIN                      1004.0
# ...                             ...                         ...
# 1265                            FIN                      1044.0
# 1276                            FIN                       941.0
# 1287                            FIN                      1049.0
# 1298                            FIN                       949.0
# 1309                            FIN                      1081.0
#
#       component_material  component_material_production_type  \
# 0                  50000                              8002.0
# 11                 50000                              8002.0
# 22                 50000                              8002.0
# 33                 50000                              8002.0
# 44                 50000                              8002.0
# ...                  ...                                 ...
# 1265               50009                              8002.0
# 1276               50009                              8002.0
# 1287               50009                              8002.0
# 1298               50009                              8002.0
# 1309               50009                              8002.0
#
#      component_material_release_type  component_material_quantity plant_id
# 0                               PROD                        990.0   RLT_10
# 11                              PROD                        960.0   RLT_10
# 22                              PROD                        968.0   RLT_10
# 33                              PROD                       1006.0   RLT_10
# 44                              PROD                       1004.0   RLT_10
# ...                              ...                          ...      ...
# 1265                            PROD                       1044.0   RLT_14
# 1276                            PROD                        941.0   RLT_14
# 1287                            PROD                       1049.0   RLT_14
# 1298                            PROD                        949.0   RLT_14
# 1309                            PROD                       1081.0   RLT_14
#
# [120 rows x 11 columns]
